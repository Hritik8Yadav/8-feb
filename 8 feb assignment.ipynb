# %% [markdown]
# ![Q 1 8 feb.jpg](attachment:ca3d410a-6823-42db-b45c-b04ac8c29866.jpg)

# %%
#Ans1: Abstraction is done to hide the internal functionality of a method in a class. This makes the class more secure.
# The abstraction can be achieved by making the public instance variables as private.
# for example:
class record:
    def __init__(self,Name,Age,Rollno):
        self.__Name=Name
        self.__Age=Age
        self.__Rollno=Rollno
    def getname(self):
        return(self.__Name)

Student=record("Hritik",21,9004)
Student.getname()
# Out:
# 'Hritik'

# %% [markdown]
# ![Q 2 8 jan.jpg](attachment:fd5aa28d-dd3f-48c4-9a49-505e96f60c9e.jpg)

# %%
#Ans 2: 
"""Abstraction means hiding of sensitive data from the accessing directly"""
"""Encapsulation means wraping up all the methods and variables in a single class so that the other class cannot
access these varibales and methods."""
# for examples 
# In the answer 2 we have defined all the instance variables as private so that they cannot be access directly this is called abstraction.
# And all the methods and variables are defined inside the record class this is encapsulation.
# Out:
# 'Encapsulation means wraping up all the methods and variables in a single class so that the other class cannot\naccess these varibales and methods.'

# %% [markdown]
# ![Q 3 8 feb.jpg](attachment:6e3cc91d-40f7-48a2-843b-234f66253051.jpg)

# %% [markdown]
# #Ans 3:
# """Abstract base class or abc module is the module used in python to prevent the object creation of a perticular class.
# It is used where the methods are not defined correctly and we are unsure that if method will work correctly """

# %% [markdown]
# ![Q 4 8 jan.jpg](attachment:b57894a9-0cef-4507-b1ac-f7b15250c42e.jpg)

# %%
# Ans 4: 
"""We can achieve data abstraction by defining the parent class as abstract class and the method as abstract method.
This will make the child classes to override the method in each classes which are inherited from the parent class."""

# %%
#Ans 5:
from abc import ABC,abstractmethod
class Student(ABC):
    @abstractmethod
    def details(self):
        pass

# %%
Hritik=Student()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[2], line 1
# ----> 1 Hritik=Student()
#
# TypeError: Can't instantiate abstract class Student with abstract method details

# %%
"""As we can see that we can't create instance of an abstract class, because the abstract class doesnot have complete implementation
and it doesnot act as """
